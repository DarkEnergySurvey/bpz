# %% [markdown]
# <h1>Visualisation of 1-d correlation output script</h1>
#
# This notebook makes plots of the output yaml files created using:
#
# <code>%>photoz-wg/systematic_tests/one_d_correlate.py SomeFile.Fits</code>

# %%
import yaml
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import glob
import seaborn as sns
sns.set(style="white")

path_to_yaml_output_files = '/Users/hoyleb/DATA/DES/PHOTOZ/'

# %% [markdown]
# <h2>Plotting stuff</h2>

# %%
almost_black = '#262626'
plt.rcParams['figure.figsize'] = (14, 8)
plt.rcParams.update({'font.size': 26, 
                     'axes.linewidth': 5,
                    'text.color': almost_black,
                    'xtick.major.size': 4,
                    'ytick.major.size': 4,
                    'legend.fancybox': True,
                    'figure.dpi': 300,
                    'legend.fontsize': 16,
                    'legend.framealpha': 0.8,
                    'legend.shadow': True,
                    'xtick.labelsize': 14,
                    'ytick.labelsize': 14})

# %%
files = glob.glob(path_to_yaml_output_files + 'CorrelationResults_1d*.yaml')[0:2]
assert len(files) > 0,'Check the file path'
print files
# Out:
# ['/Users/hoyleb/DATA/DES/PHOTOZ/CorrelationResults_1d_IM3SHAPE_Y1V1.PHOTOZ_ADA_Z_Y1_V0_3.WL_INFO_0_1M_ID.fits.yaml', '/Users/hoyleb/DATA/DES/PHOTOZ/CorrelationResults_1d_WL_INFO_0_1M_ID.PHOT0Z_Y1_BPZ_V01.IM3SHAPE_Y1V1.fits.yaml']

# %% [markdown]
# <h3>Loading in the data, and visualising it</h3>
#
# The output of the correlation script is complex, so let's extract the data we need. We'll store it in some arrays. Then we'll pass the NxN arrays to seaborn for nice plots.
#
# To save computation time, in the 1d_correlation_script, we only calcualte features correlations if i>=j.

# %%
#load in the yaml files, and extract some items of interest
for k, f1 in enumerate(files):
    res = yaml.load(open(f1, 'r'))
    #{'filename': dataFile, 'correlation_results': test_results, 'columns': cols, 'number_rows': Nrows}

    cols = res['columns']
    for i, c1 in enumerate(cols):
        
        cols2 = res['correlation_results'][c1].keys()
        MIarr = np.zeros((len(cols2), len(cols)))
        KSarr = np.zeros((len(cols2), len(cols)))
        Parr = np.zeros((len(cols2), len(cols)))
        mask = np.ones_like(MIarr, dtype=np.bool)

        for j, c2 in enumerate(cols2):

            MIarr[j,i] = res['correlation_results'][c1][c2]['MI']
            KSarr[j,i] = res['correlation_results'][c1][c2]['KS']
            Parr[j,i] = res['correlation_results'][c1][c2]['CC']
            mask[j,i] = False

            if c1 =='MEAN_PSF_FWHM' or c2=='MEAN_PSF_FWHM':
                print c1,c2,Parr[j,i], MIarr[j,i]
    #now plot the data
    
    #start with the Mutual Information
    f, ax = plt.subplots(figsize=(11, 9))
    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    sns.heatmap(MIarr, mask=mask, cmap=cmap, vmax=1.0,
                square=True,
                linewidths=.5, cbar_kws={"shrink": .5}, ax=ax, yticklabels=cols2, xticklabels=cols)

    # This sets the yticks "upright" with 0, as opposed to sideways with 90.
    plt.yticks(rotation=0) 
    plt.title('MIC: ' + f1.split('/')[-1])
    
    #now the KS- statistic. 0 = perfect agreement, >0.1 not consistent with being drawn from the same parent population
    f, ax = plt.subplots(figsize=(11, 9))
    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    sns.heatmap(KSarr,mask=mask, cmap=cmap, vmax=np.amax(KSarr),
                square=True,
                linewidths=.5, cbar_kws={"shrink": .5}, ax=ax, yticklabels=cols2, xticklabels=cols)

    # This sets the yticks "upright" with 0, as opposed to sideways with 90.
    plt.yticks(rotation=0) 
    plt.title('KS test: ' + f1.split('/')[-1])

    
    #Show the Pearson correlation coefficient.
    f, ax = plt.subplots(figsize=(11, 9))
    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    sns.heatmap(Parr, mask=mask, cmap=cmap, vmax=np.amax(Parr),
                square=True,
                linewidths=.5, cbar_kws={"shrink": .5}, ax=ax, yticklabels=cols2, xticklabels=cols)

    # This sets the yticks "upright" with 0, as opposed to sideways with 90.
    plt.yticks(rotation=0) 
    plt.title('CC: ' + f1.split('/')[-1])
# Out:
# MEDIAN_Z MEAN_PSF_FWHM -0.0193543573473 0.000309427734986
# Z_MC MEAN_PSF_FWHM -0.0155751557721 0.000175165933363
# MEDIAN_Z MEAN_PSF_FWHM -0.00428526645612 0.000490685282907
# Z_MC MEAN_PSF_FWHM -0.00435627772403 0.00027873840709

# %%
res['correlation_results'][c1][c2]
# Out:
# {'CC': nan, 'KS': 1.0, 'MI': inf}

# %%
import sml_mla as ml
import minepy as MINE
import bh_photo_z_validation as pval
import numpy as np
import ml_metrics as ml_m

filen = 'IM3SHAPE_Y1V1.PHOTOZ_ADA_Z_Y1_V0_3.WL_INFO_0_1M_ID.fits'
#get data to determine weights
xlab = 'MEAN_PSF_FWHM'
ylab = 'MEAN_Z'
arr, _ = ml.dataSet('/Users/hoyleb/DATA/DES/PHOTOZ/' + filen, 
                    [xlab, ylab, 'N_EXPOSURE', 'INFO_FLAG'], ['COADD_OBJECTS_ID']).loadData()

# %%
ind = (arr[:, 0] > 0) * (arr[:, 0] < 100) * (arr[: ,2] ==4) * (arr[: ,3] == 0)
arr = arr[ind]

# %%
r = np.arange(len(arr))
for i1 in np.logspace(2,5, 50):
    i = int(i1)
    np.random.shuffle(r)
    
    KS_ = pval.ks_test(arr[r[0: i],0], arr[r[0: i],1])
    CC_ = np.corrcoef(arr[r[0: i],0], arr[r[0: i],1])
    MI_ = ml_m.mutualInformation(arr[r[0: i],0], arr[r[0: i],1])
    
    print i,  KS_, MI_, CC_[0,1]

# %%
"MEDIAN_Z MEAN_PSF_FWHM -0.0197448562705 0.0297004109429"

# %%
bns = np.arange(0, 50 ,0.1)
bn = bns[1:] - bns[1]/2.0
x = []
y = []
yerr = []
N = []
for i in range(len(bns)-1):
    ind1 = (arr[:, 0] < bns[i + 1]) * (arr[:, 0] >= bns[i])
    x.append(np.mean(arr[ind1, 0]))
    y.append(np.mean(arr[ind1, 1]))
    yerr.append(np.std(arr[ind1, 1])*0.01)
    N.append(np.sum(ind1))
plt.errorbar(x, y, yerr=yerr ,fmt='o')
plt.title(filen)
#plt.xlim(3.2,4.8)
#plt.ylim(0.63, 0.68)
plt.xlabel(xlab)
plt.ylabel(ylab)
f= plt.figure()
plt.plot(x, N)
plt.ylabel('Number')
plt.ylabel(xlab)
#plt.xlim(3.2,4.8)
